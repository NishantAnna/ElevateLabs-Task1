# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\NISHANT\OneDrive\Desktop\DataSets\archive\archive (2)\noshowappointments.csv")

# %%
df
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 0       2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1       5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2       4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3       8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4       8.841186e+12        5642494      F  2016-04-29T16:07:23Z
# ...              ...            ...    ...                   ...
# 110522  2.572134e+12        5651768      F  2016-05-03T09:15:35Z
# 110523  3.596266e+12        5650093      F  2016-05-03T07:27:33Z
# 110524  1.557663e+13        5630692      F  2016-04-27T16:03:52Z
# 110525  9.213493e+13        5630323      F  2016-04-27T15:09:23Z
# 110526  3.775115e+14        5629448      F  2016-04-27T13:30:56Z
#
#               AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0       2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# ...

# %%
df.head()
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# ...

# %%
df.tail()
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 110522  2.572134e+12        5651768      F  2016-05-03T09:15:35Z
# 110523  3.596266e+12        5650093      F  2016-05-03T07:27:33Z
# 110524  1.557663e+13        5630692      F  2016-04-27T16:03:52Z
# 110525  9.213493e+13        5630323      F  2016-04-27T15:09:23Z
# 110526  3.775115e+14        5629448      F  2016-04-27T13:30:56Z
#
#               AppointmentDay  Age Neighbourhood  Scholarship  Hipertension  \
# 110522  2016-06-07T00:00:00Z   56   MARIA ORTIZ            0             0
# 110523  2016-06-07T00:00:00Z   51   MARIA ORTIZ            0             0
# 110524  2016-06-07T00:00:00Z   21   MARIA ORTIZ            0             0
# 110525  2016-06-07T00:00:00Z   38   MARIA ORTIZ            0             0
# 110526  2016-06-07T00:00:00Z   54   MARIA ORTIZ            0             0
#
#         Diabetes  Alcoholism  Handcap  SMS_received No-show
# 110522         0           0        0             1      No
# ...

# %%
df.isnull()
# Out:
#         PatientId  AppointmentID  Gender  ScheduledDay  AppointmentDay    Age  \
# 0           False          False   False         False           False  False
# 1           False          False   False         False           False  False
# 2           False          False   False         False           False  False
# 3           False          False   False         False           False  False
# 4           False          False   False         False           False  False
# ...           ...            ...     ...           ...             ...    ...
# 110522      False          False   False         False           False  False
# 110523      False          False   False         False           False  False
# 110524      False          False   False         False           False  False
# 110525      False          False   False         False           False  False
# 110526      False          False   False         False           False  False
#
# ...

# %%
df.isnull().sum()
# Out:
# PatientId         0
# AppointmentID     0
# Gender            0
# ScheduledDay      0
# AppointmentDay    0
# Age               0
# Neighbourhood     0
# Scholarship       0
# Hipertension      0
# Diabetes          0
# Alcoholism        0
# Handcap           0
# SMS_received      0
# No-show           0
# dtype: int64

# %%
df_clean=df.dropna()

# %%
df_fill=df.fillna(0)

# %%
df.drop_duplicates()
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 0       2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1       5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2       4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3       8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4       8.841186e+12        5642494      F  2016-04-29T16:07:23Z
# ...              ...            ...    ...                   ...
# 110522  2.572134e+12        5651768      F  2016-05-03T09:15:35Z
# 110523  3.596266e+12        5650093      F  2016-05-03T07:27:33Z
# 110524  1.557663e+13        5630692      F  2016-04-27T16:03:52Z
# 110525  9.213493e+13        5630323      F  2016-04-27T15:09:23Z
# 110526  3.775115e+14        5629448      F  2016-04-27T13:30:56Z
#
#               AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0       2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# ...

# %%
duplicates=df[df.duplicated()]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [PatientId, AppointmentID, Gender, ScheduledDay, AppointmentDay, Age, Neighbourhood, Scholarship, Hipertension, Diabetes, Alcoholism, Handcap, SMS_received, No-show]
# Index: []

# %%
duplicates=[df.duplicated()]
print(duplicates)
# Out:
# [0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 110522    False
# 110523    False
# 110524    False
# 110525    False
# 110526    False
# Length: 110527, dtype: bool]

# %%
df["Gender"].str.lower()
# Out:
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
#           ...
# 110522    None
# 110523    None
# 110524    None
# 110525    None
# 110526    None
# Name: Gender, Length: 110527, dtype: object

# %%
df["Gender"].str.capitalize()
# Out:
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
#           ...
# 110522    None
# 110523    None
# 110524    None
# 110525    None
# 110526    None
# Name: Gender, Length: 110527, dtype: object

# %%
df
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 0       2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1       5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2       4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3       8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4       8.841186e+12        5642494      F  2016-04-29T16:07:23Z
# ...              ...            ...    ...                   ...
# 110522  2.572134e+12        5651768      F  2016-05-03T09:15:35Z
# 110523  3.596266e+12        5650093      F  2016-05-03T07:27:33Z
# 110524  1.557663e+13        5630692      F  2016-04-27T16:03:52Z
# 110525  9.213493e+13        5630323      F  2016-04-27T15:09:23Z
# 110526  3.775115e+14        5629448      F  2016-04-27T13:30:56Z
#
#               AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0       2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# ...

# %%
df["Gender"].replace({
    "M": "Male", "male": "Male",
    "F": "Female", "female": "Female"
})
# Out:
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
#           ...
# 110522    None
# 110523    None
# 110524    None
# 110525    None
# 110526    None
# Name: Gender, Length: 110527, dtype: object

# %%
df
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 0       2.987250e+13        5642903   None  2016-04-29T18:38:08Z
# 1       5.589978e+14        5642503   None  2016-04-29T16:08:27Z
# 2       4.262962e+12        5642549   None  2016-04-29T16:19:04Z
# 3       8.679512e+11        5642828   None  2016-04-29T17:29:31Z
# 4       8.841186e+12        5642494   None  2016-04-29T16:07:23Z
# ...              ...            ...    ...                   ...
# 110522  2.572134e+12        5651768   None  2016-05-03T09:15:35Z
# 110523  3.596266e+12        5650093   None  2016-05-03T07:27:33Z
# 110524  1.557663e+13        5630692   None  2016-04-27T16:03:52Z
# 110525  9.213493e+13        5630323   None  2016-04-27T15:09:23Z
# 110526  3.775115e+14        5629448   None  2016-04-27T13:30:56Z
#
#               AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0       2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# ...

# %%
df.replace({"Gender": {
    "M": "Male", "male": "Male",
    "F": "Female", "female": "Female"
}}, inplace=True)

# %%
df
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 0       2.987250e+13        5642903   None  2016-04-29T18:38:08Z
# 1       5.589978e+14        5642503   None  2016-04-29T16:08:27Z
# 2       4.262962e+12        5642549   None  2016-04-29T16:19:04Z
# 3       8.679512e+11        5642828   None  2016-04-29T17:29:31Z
# 4       8.841186e+12        5642494   None  2016-04-29T16:07:23Z
# ...              ...            ...    ...                   ...
# 110522  2.572134e+12        5651768   None  2016-05-03T09:15:35Z
# 110523  3.596266e+12        5650093   None  2016-05-03T07:27:33Z
# 110524  1.557663e+13        5630692   None  2016-04-27T16:03:52Z
# 110525  9.213493e+13        5630323   None  2016-04-27T15:09:23Z
# 110526  3.775115e+14        5629448   None  2016-04-27T13:30:56Z
#
#               AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0       2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# ...

# %%
df1=pd.read_csv(r"C:\Users\NISHANT\OneDrive\Desktop\DataSets\archive\archive (2)\noshowappointments.csv")

# %%
df1
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 0       2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1       5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2       4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3       8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4       8.841186e+12        5642494      F  2016-04-29T16:07:23Z
# ...              ...            ...    ...                   ...
# 110522  2.572134e+12        5651768      F  2016-05-03T09:15:35Z
# 110523  3.596266e+12        5650093      F  2016-05-03T07:27:33Z
# 110524  1.557663e+13        5630692      F  2016-04-27T16:03:52Z
# 110525  9.213493e+13        5630323      F  2016-04-27T15:09:23Z
# 110526  3.775115e+14        5629448      F  2016-04-27T13:30:56Z
#
#               AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0       2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# ...

# %%
df1['Gender'].value_counts()
# Out:
# Gender
# F    71840
# M    38687
# Name: count, dtype: int64

# %%
df1['Gender'] = df1['Gender'].replace({"F": 'Female', "M": 'Male'})

# %%
df1['Gender'].value_counts()
# Out:
# Gender
# Female    71840
# Male      38687
# Name: count, dtype: int64

# %%
df1.dtypes
# Out:
# PatientId         float64
# AppointmentID       int64
# Gender             object
# ScheduledDay       object
# AppointmentDay     object
# Age                 int64
# Neighbourhood      object
# Scholarship         int64
# Hipertension        int64
# Diabetes            int64
# Alcoholism          int64
# Handcap             int64
# SMS_received        int64
# No-show            object
# dtype: object

# %%
df1['AppointmentDay'] = pd.to_datetime(df1['AppointmentDay'])

# %%
df1.dtypes
# Out:
# PatientId                     float64
# AppointmentID                   int64
# Gender                         object
# ScheduledDay      datetime64[ns, UTC]
# AppointmentDay                 object
# Age                             int64
# Neighbourhood                  object
# Scholarship                     int64
# Hipertension                    int64
# Diabetes                        int64
# Alcoholism                      int64
# Handcap                         int64
# SMS_received                    int64
# No-show                        object
# dtype: object

# %%
df1['ScheduledDay'] = pd.to_datetime(df1['ScheduledDay'])

# %%
df1.dtypes
# Out:
# PatientId                     float64
# AppointmentID                   int64
# Gender                         object
# ScheduledDay      datetime64[ns, UTC]
# AppointmentDay    datetime64[ns, UTC]
# Age                             int64
# Neighbourhood                  object
# Scholarship                     int64
# Hipertension                    int64
# Diabetes                        int64
# Alcoholism                      int64
# Handcap                         int64
# SMS_received                    int64
# No-show                        object
# dtype: object

# %%
df1.head()
# Out:
#       PatientId  AppointmentID  Gender              ScheduledDay  \
# 0  2.987250e+13        5642903  Female 2016-04-29 18:38:08+00:00
# 1  5.589978e+14        5642503    Male 2016-04-29 16:08:27+00:00
# 2  4.262962e+12        5642549  Female 2016-04-29 16:19:04+00:00
# 3  8.679512e+11        5642828  Female 2016-04-29 17:29:31+00:00
# 4  8.841186e+12        5642494  Female 2016-04-29 16:07:23+00:00
#
#              AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0 2016-04-29 00:00:00+00:00   62    JARDIM DA PENHA            0
# 1 2016-04-29 00:00:00+00:00   56    JARDIM DA PENHA            0
# 2 2016-04-29 00:00:00+00:00   62      MATA DA PRAIA            0
# 3 2016-04-29 00:00:00+00:00    8  PONTAL DE CAMBURI            0
# 4 2016-04-29 00:00:00+00:00   56    JARDIM DA PENHA            0
#
#    Hipertension  Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0             1         0           0        0             0      No
# ...

# %%
df1.columns = df1.columns.str.lower()

# %%
df1
# Out:
#            patientid  appointmentid  gender              scheduledday  \
# 0       2.987250e+13        5642903  Female 2016-04-29 18:38:08+00:00
# 1       5.589978e+14        5642503    Male 2016-04-29 16:08:27+00:00
# 2       4.262962e+12        5642549  Female 2016-04-29 16:19:04+00:00
# 3       8.679512e+11        5642828  Female 2016-04-29 17:29:31+00:00
# 4       8.841186e+12        5642494  Female 2016-04-29 16:07:23+00:00
# ...              ...            ...     ...                       ...
# 110522  2.572134e+12        5651768  Female 2016-05-03 09:15:35+00:00
# 110523  3.596266e+12        5650093  Female 2016-05-03 07:27:33+00:00
# 110524  1.557663e+13        5630692  Female 2016-04-27 16:03:52+00:00
# 110525  9.213493e+13        5630323  Female 2016-04-27 15:09:23+00:00
# 110526  3.775115e+14        5629448  Female 2016-04-27 13:30:56+00:00
#
#                   appointmentday  age      neighbourhood  scholarship  \
# ...

# %%
df1['neighbourhood']=df1['neighbourhood'].astype(str)

# %%
df1.dtypes
# Out:
# patientid                     float64
# appointmentid                   int64
# gender                         object
# scheduledday      datetime64[ns, UTC]
# appointmentday    datetime64[ns, UTC]
# age                             int64
# neighbourhood                  object
# scholarship                     int64
# hipertension                    int64
# diabetes                        int64
# alcoholism                      int64
# handcap                         int64
# sms_received                    int64
# no-show                        object
# dtype: object

# %%
df1['patientid']=df1['patientid'].astype(int)

# %%
df1.dtypes
# Out:
# patientid                       int32
# appointmentid                   int64
# gender                         object
# scheduledday      datetime64[ns, UTC]
# appointmentday    datetime64[ns, UTC]
# age                             int64
# neighbourhood                  object
# scholarship                     int64
# hipertension                    int64
# diabetes                        int64
# alcoholism                      int64
# handcap                         int64
# sms_received                    int64
# no-show                        object
# dtype: object

# %%
df1
# Out:
#          patientid  appointmentid  gender              scheduledday  \
# 0      -2147483648        5642903  Female 2016-04-29 18:38:08+00:00
# 1      -2147483648        5642503    Male 2016-04-29 16:08:27+00:00
# 2      -2147483648        5642549  Female 2016-04-29 16:19:04+00:00
# 3      -2147483648        5642828  Female 2016-04-29 17:29:31+00:00
# 4      -2147483648        5642494  Female 2016-04-29 16:07:23+00:00
# ...            ...            ...     ...                       ...
# 110522 -2147483648        5651768  Female 2016-05-03 09:15:35+00:00
# 110523 -2147483648        5650093  Female 2016-05-03 07:27:33+00:00
# 110524 -2147483648        5630692  Female 2016-04-27 16:03:52+00:00
# 110525 -2147483648        5630323  Female 2016-04-27 15:09:23+00:00
# 110526 -2147483648        5629448  Female 2016-04-27 13:30:56+00:00
#
#                   appointmentday  age      neighbourhood  scholarship  \
# 0      2016-04-29 00:00:00+00:00   62    JARDIM DA PENHA            0
# ...
